# %% [markdown]
# ## Streamlit
# Streamlit is an open-source app framework for Machine Learning and Data Science projects. It allows you to create beautiful web applicationsfor you machine learning and data science projects with simple python.
