# %% [markdown]
# ## Parts of Speech Tag

# %% [markdown]
# "Shahi Qilla is a beautiful mornument"

# %%
'''CC coordinating conjunction 
CD cardinal digit 
DT determiner 
EX existential there (like: “there is” … think of it like “there exists”) 
FW foreign word 
IN preposition/subordinating conjunction 
JJ adjective – ‘big’ 
JJR adjective, comparative – ‘bigger’ 
JJS adjective, superlative – ‘biggest’ 
LS list marker 1) 
MD modal – could, will 
NN noun, singular ‘- desk’ 
NNS noun plural – ‘desks’ 
NNP proper noun, singular – ‘Harrison’ 
NNPS proper noun, plural – ‘Americans’ 
PDT predeterminer – ‘all the kids’ 
POS possessive ending parent’s 
PRP personal pronoun –  I, he, she 
PRP$ possessive pronoun – my, his, hers 
RB adverb – very, silently, 
RBR adverb, comparative – better 
RBS adverb, superlative – best 
RP particle – give up 
TO – to go ‘to’ the store. 
UH interjection – errrrrrrrm 
VB verb, base form – take 
VBD verb, past tense – took 
VBG verb, gerund/present participle – taking 
VBN verb, past participle – taken 
VBP verb, sing. present, non-3d – take 
VBZ verb, 3rd person sing. present – takes 
WDT wh-determiner – which 
WP wh-pronoun – who, what 
WP$ possessive wh-pronoun, eg- whose 
WRB wh-adverb, eg- where, when'''
# Out:
# 'CC coordinating conjunction \nCD cardinal digit \nDT determiner \nEX existential there (like: “there is” … think of it like “there exists”) \nFW foreign word \nIN preposition/subordinating conjunction \nJJ adjective – ‘big’ \nJJR adjective, comparative – ‘bigger’ \nJJS adjective, superlative – ‘biggest’ \nLS list marker 1) \nMD modal – could, will \nNN noun, singular ‘- desk’ \nNNS noun plural – ‘desks’ \nNNP proper noun, singular – ‘Harrison’ \nNNPS proper noun, plural – ‘Americans’ \nPDT predeterminer – ‘all the kids’ \nPOS possessive ending parent’s \nPRP personal pronoun –  I, he, she \nPRP$ possessive pronoun – my, his, hers \nRB adverb – very, silently, \nRBR adverb, comparative – better \nRBS adverb, superlative – best \nRP particle – give up \nTO – to go ‘to’ the store. \nUH interjection – errrrrrrrm \nVB verb, base form – take \nVBD verb, past tense – took \nVBG verb, gerund/present participle – taking \nVBN verb, past participle – taken \nVBP verb, sing. present, non-3d – 
# ...

# %%
### Summary of the novel "The art of being alone"
paragraph = """The deep thing is we don’t feel lonely when nobody is around us, but the loneliness occurs when you can not find yourself inside you. The biggest loss is not to lose others but to lose ourselves in the search for others.

There are some days when you miss yourself more than you have ever missed anyone else. Nobody will stay with you for a lifetime, but there is always one person who will stay with you: YOU. The most important person in your life must be you, no one else. You deserve your love, care, and attention, too.

Self-love starts with self-acceptance. Accept your flaws, your scars, your hidden talent, your worth, and your true self. You don’t need to pretend like anyone else in front of you. Know yourself and be selfish. According to society, we must be good & caring people. And we all try to be like that person in our whole lives. sometime we hide our true emotions from everyone. Here you should need to free yourself from any burden and start treating yourself as a human who has different emotions, anger, fear, love, sadness, and so on. You don’t have to be ashamed of reacting to what you feel.

And most importantly, learning about yourself is a lifelong process, you change a little every day. So, keep learning about yourself, and make time for yourself. Listen to your inner voice.

And make your alone time your growth period. Spending Excessive time with others pay you nothing. but when you spend your alone time to learn something that will definitely help you to grow. Whenever you find yourself lonely, turn this time into an opportunity and learn new things. There are thousands of skills, hobbies, and much more to learn. And everything is easily available at our fingertips. Learn new things, try to develop new hobbies, do exercise, read books, and make efforts to improve yourself to become better day by day.

In the last, become independent not just financially but emotionally too. Attachments with people may hurt you, but falling in love with yourself will never.

"""

# %%
# !python -m pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download("averaged_perceptron_tagger_eng")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.

# %%
sentences = nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['The deep thing is we don’t feel lonely when nobody is around us, but the loneliness occurs when you can not find yourself inside you.',
#  'The biggest loss is not to lose others but to lose ourselves in the search for others.',
#  'There are some days when you miss yourself more than you have ever missed anyone else.',
#  'Nobody will stay with you for a lifetime, but there is always one person who will stay with you: YOU.',
#  'The most important person in your life must be you, no one else.',
#  'You deserve your love, care, and attention, too.',
#  'Self-love starts with self-acceptance.',
#  'Accept your flaws, your scars, your hidden talent, your worth, and your true self.',
#  'You don’t need to pretend like anyone else in front of you.',
#  'Know yourself and be selfish.',
#  'According to society, we must be good & caring people.',
#  'And we all try to be like that person in our whole lives.',
#  'sometime we hide our true emotions from everyone.',
# ...

# %%
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
print(nltk.__version__)
# Out:
# 3.9.4

# %%
##We will find the paarts of speech tagger
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in set(stopwords.words("english"))]
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('The', 'DT'), ('deep', 'JJ'), ('thing', 'NN'), ('’', 'JJ'), ('feel', 'NN'), ('lonely', 'RB'), ('nobody', 'NN'), ('around', 'IN'), ('us', 'PRP'), (',', ','), ('loneliness', 'JJ'), ('occurs', 'RB'), ('find', 'VBP'), ('inside', 'JJ'), ('.', '.')]
# [('The', 'DT'), ('biggest', 'JJS'), ('loss', 'NN'), ('lose', 'JJ'), ('others', 'NNS'), ('lose', 'VBP'), ('search', 'NN'), ('others', 'NNS'), ('.', '.')]
# [('There', 'EX'), ('days', 'NNS'), ('miss', 'VBP'), ('ever', 'RB'), ('missed', 'VBN'), ('anyone', 'NN'), ('else', 'RB'), ('.', '.')]
# [('Nobody', 'NN'), ('stay', 'NN'), ('lifetime', 'RB'), (',', ','), ('always', 'RB'), ('one', 'CD'), ('person', 'NN'), ('stay', 'NN'), (':', ':'), ('YOU', 'NN'), ('.', '.')]
# [('The', 'DT'), ('important', 'JJ'), ('person', 'NN'), ('life', 'NN'), ('must', 'MD'), (',', ','), ('one', 'CD'), ('else', 'RB'), ('.', '.')]
# [('You', 'PRP'), ('deserve', 'VBP'), ('love', 'VB'), (',', ','), ('care', 'NN'), (',', ','), ('attention', 'NN'), (',', ','), ('.', '.')]
# ...

# %%
"Shahi Qilla is a beautiful mornument".split()
# Out:
# ['Shahi', 'Qilla', 'is', 'a', 'beautiful', 'mornument']

# %%
print(nltk.pos_tag("Shahi Qilla is beautiful mornument".split()))
# Out:
# [('Shahi', 'NNP'), ('Qilla', 'NNP'), ('is', 'VBZ'), ('beautiful', 'JJ'), ('mornument', 'NN')]
