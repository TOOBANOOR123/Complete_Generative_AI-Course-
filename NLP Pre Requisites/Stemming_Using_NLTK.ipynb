# %% [markdown]
# ## Stemming
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of the words known as lemma. Stemming is important in natural language understanding (NLU) and natural language processing (NLP).

# %%
## Classification Problem 
## Comments of a product is a positive review or negative review 
##  Reviews----> eating, eat,eaten [going,gone,goes]--->go
words = ['eating', 'eats', 'eaten', 'writing', 'writes', 'programming', 'programs', 'history', 'finally']

# %% [markdown]
# ## Porter Stemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word+"----->"+stemming.stem(word))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eaten
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->histori
# finally----->final

# %%
stemming.stem("Congratulations")
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# ## RegexpStemmer Class
# NLTK has a RegexpStemmer class with the help of which we can easily implement Regular Expression Stemmer algorithms. It basically takes a single regular expression and removes any suffix or prefix that matches the expression.

# %%
from nltk.stem import RegexpStemmer

# %%
regex_stemmer = RegexpStemmer("able$|ing$|s$|", min=4)

# %%
regex_stemmer.stem('eating')
# Out:
# 'eat'

# %%
regex_stemmer.stem("capable")
# Out:
# 'cap'

# %%
regex_stemmer.stem("Cars")
# Out:
# 'Car'

# %%
regex_stemmer.stem("ingeating")
# Out:
# 'ingeat'

# %% [markdown]
# ## Snowball Stemmer
# It is a stemming algorithm which is also known as the porter2 stemming algorithm. it is the better version of porter stemmer since some issues of it were fixed in this stemmer.

# %%
from nltk.stem import SnowballStemmer

# %%
snowball_stem = SnowballStemmer('english')

# %%
words = ['eating', 'eats', 'eaten', 'writing', 'writes', 'programming', 'programs', 'history', 'finally']
for word in words:
    print(word+"--->"+snowball_stem.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finally--->final

# %%
snowball_stem.stem("Finally")
# Out:
# 'final'

# %%
snowball_stem.stem("fairly")
# Out:
# 'fair'

# %%
snowball_stem.stem("history")
# Out:
# 'histori'

# %%
stemming.stem("history")
# Out:
# 'histori'

# %%
stemming.stem("fairly")
# Out:
# 'fairli'

# %%
snowball_stem.stem("gone"), snowball_stem.stem("goes")
# Out:
# ('gone', 'goe')

# %%
stemming.stem("gone"), stemming.stem("goes")
# Out:
# ('gone', 'goe')
